# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import html5lib
import numpy as np
import warnings
warnings.filterwarnings(action='ignore')

# %%
products1 = {
    '제품명' : [],
    '관리번호' : [],
    '성상' : [],
    '업체명' : [],
    '섭취방법' : [],
    '보관방법' : [],
    '주의사항' : [],
    '효능' : [],
    '기타' : []
}

# %%
len(products1['업체명'])
# Out:
# 18699

# %%
try:
    for idx in np.arange(3667, 4030):
        url1 = f'https://www.fmis.kr/public/pro/hpt/GbinHtfsPrductTrgetList.do?guPrdlstMnfManageNo=0&pageIndex={idx}&pageNo=4030600&searchCnd=99&searchWrd='
        df1 = pd.read_html(url1, encoding='utf-8')
        product_nums1 = df1[0]['품목 제조 관리번호']

        for product_num1 in product_nums1:
            info_url1 = f'https://www.fmis.kr/public/pro/hpt/selectHtfsPrductTrgetInfo.do?guPrdlstMnfManageNo={product_num1}&pageIndex={idx}&pageNo=4030600&searchCnd=99&searchWrd='
            headers = {'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36',
                      'cookie' : 'JSESSIONID=3D0B66A897BF73D85A59B2EDD6C3960F.worker1; _gid=GA1.2.556744064.1686460481; _ga_H9T4K79JBD=GS1.1.1686482896.4.1.1686483468.0.0.0; _ga=GA1.2.1465316723.1686460481; _gat_gtag_UA_153717896_1=1',
                      'host' : 'www.fmis.kr',
                       'Accept-Language' : 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7'
                      }
            res1 = requests.get(info_url1, headers=headers, verify=False)
            soup1 = BeautifulSoup(res1.text, 'html.parser')
            try:
                board1 = soup1.select_one('div.board_view')
                products1['제품명'].append(board1.select_one('div.board_view.big > div > dl:nth-child(1) > dd').text)
                products1['관리번호'].append(board1.select_one('div.board_view.big > div > dl:nth-child(10) > dd').text)
                products1['성상'].append(board1.select_one('div.board_view.big > div > dl:nth-child(3) > dd').text)
                products1['업체명'].append(board1.select_one('div.board_view.big > div > dl:nth-child(4) > dd').text)
                products1['섭취방법'].append(board1.select_one('div.board_view.big > div > dl:nth-child(5) > dd').text)
                products1['보관방법'].append(board1.select_one('div.board_view.big > div > dl:nth-child(6) > dd').text)
                products1['주의사항'].append(board1.select_one('div.board_view.big > div > dl:nth-child(7) > dd').text)
                products1['효능'].append(board1.select_one('div.board_view.big > div > dl:nth-child(8) > dd').text)
                products1['기타'].append(board1.select_one('div.board_view.big > div > dl:nth-child(9) > dd').text)
            except:
                pass
            
except Exception as e:
    print(e)
    print(product_num1)
    print(idx)
# Out:
# HTTP Error 500: 500
# 20040020020284
# 3667

# %%
df = pd.DataFrame(products1)
df.drop_duplicates(inplace=True)
df.to_csv('product.csv',encoding='utf-8', index=False)

# %%
df1 = pd.read_csv('product.csv')
df1
# Out:
#                        제품명             관리번호
# 0                마더스 철분 30  201000190041288  \
# 1                     관절편한    2021001622939
# 2                  다이어트 츄잉   20040020071461
# 3               더마뷰티 스킨부스터  200400200023414
# 4                    리버골드F  200400200072987
# ...                    ...              ...
# 19338         퓨어온 마그네슘 트리플   20040020046473
# 19339           돌외잎다운 다이어트   20040020068317
# 19340          프로바이오틱스 에이스   20040020068316
# 19341            홍삼정농축분말로얄   20040020013273
# 19342  서흥 남성을 위한 멀티비타민 미네랄  200400200061105
#
#                                                      성상          업체명
# 0              고유의 향미가 있고 이미, 이취가 없는 밝은 흰 노란색의 장방형 제피정제      엔피케이(주)  \
# 1                    고유의 향미가 있고 이미, 이취가 없으며 밝은 연노란색의 액상  엔피케이(주) 2공장
# 2                  고유의 향미가 있고, 이미,이취가없는 연한 노란 분홍색의 원형정제    에프엔바이오(주)
# 3      고유의 향미가 있고 이미, 이취가 없는 갈색의 내용물을 함유한 갈흑색의 타원형 연질캡슐   코스맥스바이오(주)
# 4                   고유의 향미가 있고 이미·이취가 없는 노란색의 타원형 제피 정제   (주)한국씨엔에스팜
# ...                                                 ...          ...
# 19338                     고유의 향미가 있고 이미∙이취가 없는 흰색의 코팅정제    한국바이오팜(주)
# 19339                          황갈색 장방형 제피정제로 이미, 이취가 없음     극동에치팜(주)
# 19340                   미백색 내용물을 가진 백색 경질캡슐로 이미, 이취가 없음     극동에치팜(주)
# 19341                               고유의 암갈색과 향미를 가지는 분말    (주)한국인삼공사
# 19342                     탁한 주황색의 점조성 내용물을 함유한 암갈색 연질캡슐        (주)서흥
#
#                                                     섭취방법  보관방법
# 0                                  1일 1회, 1회 1정 물과 함께 섭취   NaN  \
# 1                                  1일 1회, 1회 1포를 섭취하십시오.   NaN
# 2                                    1일 4회 1회 1정을 씹어드십시오   NaN
# 3      1일 1회, 1회 2캡슐을 충분한 물과 함께 섭취하십시오. 1일 2회, 1회 1캡슐...   NaN
# 4                        1일 1회, 1회 1정을 충분한 물과 함께 섭취하십시오.   NaN
# ...                                                  ...   ...
# 19338                          1일 1회, 1회 1정을 물과 함께 섭취한다.   NaN
# 19339                            1일 1회, 1회 2정을 물과 함께 섭취.   NaN
# 19340                           1일 1회, 1회 1캡슐을 물과 함께 섭취.   NaN
# 19341                 1일 1회, 1회 1포(2 g)를 그대로 또는 물에 타서 섭취   NaN
# 19342            1일 1회, 1회 1캡슐(1.6 g)을 충분한 물과 함께 섭취하십시오.   NaN
#
#                                                     주의사항
# 0      1) 과량섭취 시 부작용이 있을 수 있음.\n2) 특정원료에 알레르기가 있거나 질병...  \
# 1      1) 과량섭취 시 부작용이 있을 수 있음.\n2) 특정원료에 알레르기가 있거나 질병...
# 2      (가) 어린이, 임산부 및 수유부는 섭취를 피할 것\n(나) 간·신장·심장질환, 알...
# 3      섭취 시 목에 걸릴 수 있으므로 반드시 물과 함께 섭취하십시오. \n섭취 시 위장장...
# 4      ① 이상사례 발생 시 섭취를 중단하고 전문가와 상담하시기 바랍니다.\n② 알레르기 ...
# ...                                                  ...
# 19338  1. 알레르기나 특이체질이신 경우 성분을 확인하신 후 섭취하시기 바랍니다.\n2. ...
# 19339  과량섭취시 위장장애(구토와 위장운동 증가)가 발생할 수 있음\n임산부, 수유부, 특...
# 19340  임산부, 수유부, 특이체질, 알레르기 체질인 경우 개인에 따라 과민반응을 나타낼 수...
# 19341                     의약품(당뇨치료제, 혈액항응고제) 복용 시 섭취에 주의
# 19342                            특히 6세 이하는 과량섭취하지 않도록 주의
#
#                                                       효능
# 0                       [철]①체내 산소운반과 혈액생성에 필요②에너지 생성에 필요  \
# 1                      [엠에스엠(MSM)]①관절 및 연골건강에 도움을 줄 수 있음
# 2      [가르시니아캄보지아추출물]탄수화물이 지방으로 합성되는 것을 억제하여 체지방 감소에 ...
# 3      1) 로즈마리추출물등복합물 : 자외선에 의한 피부손상으로부터 피부 건강 유지에 도움...
# 4      [밀크씨슬추출물] 간 건강에 도움을 줄 수 있음\n[비타민 B1] 탄수화물과 에너지...
# ...                                                  ...
# 19338  ①에너지 이용에 필요②신경과 근육 기능 유지에 필요\n\n①단백질 및 아미노산 이용...
# 19339  체지방 감소에 도움을 줄 수 있음 (생리활성기능 2등급)\n\n①어두운 곳에서 시각...
# 19340  ①유산균 증식 및 유해균 억제에 도움을 줄 수 있음 ②배변활동 원활에 도움을 줄 수 있음
# 19341  ①면역력 증진에 도움을 줄 수 있음②피로개선에 도움을 줄 수 있음③혈소판 응집 억제...
# 19342  ①뼈 형성에 필요②에너지 이용에 필요③유해산소로부터 세포를 보호하는데 필요\n\n①...
#
#                                                       기타
# 0      1) 성상 : 고유의 향미가 있고 이미, 이취가 없는 밝은 흰 노란색의 장방형 제피...
# 1      1) 성상 : 고유의 향미가 있고 이미, 이취가 없으며 밝은 연노란색의 액상\n2)...
# 2      성상 : 고유의 향미가 있고, 이미,이취가없는 연한 노란 분홍색의 원형정제\n - ...
# 3      1) 성상 : 고유의 향미가 있고 이미, 이취가 없는 갈색의 내용물을 함유한 갈흑색...
# 4      1) 성상 : 고유의 향미가 있고 이미·이취가 없는 노란색의 타원형 제피 정제\n2...
# ...                                                  ...
# 19338  1) 성상 : 고유의 향미가 있고 이미∙이취가 없는 흰색의 코팅정제\n2) 마그네슘...
# 19339  1. 성상 : 황갈색 장방형 제피정제로 이미, 이취가 없음\n2. Damulin A...
# 19340  1. 성상 : 미백색 내용물을 가진 백색 경질캡슐로 이미, 이취가 없음\n2. 프로...
# 19341  1) 성상 : 고유의 암갈색과 향미를 가지는 분말\n2) 진세노사이드 Rg1, Rb...
# 19342  1) 성상 : 탁한 주황색의 점조성 내용물을 함유한 암갈색 연질캡슐\n2) 칼슘 :...
#
# [19343 rows x 9 columns]
